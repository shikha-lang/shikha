# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # importing order data

# %%
#Pathway to the Dataframes
path = r'/Users/spathak/Instacart_Basket_Analysis' - Projects\Data Immersion\Data Immersion A4\04-2023 Instacart Basket Analysis'

# %%
path = r'/Users/spathak/Instacart_Basket_Analysis'

# %%
#Importing orders_consistency.csv dataframe
df_ords = pd.read_csv(os.path.join(path, '02-Data', 'Prepared-Data','orders_data_Consistency.csv'), index_col = False)

# %%
#Importing order_products_prior.csv dataframe
df_ords_prior = pd.read_csv(os.path.join(path, '02-Data', 'Original-Data', 'order_products_prior.csv'), index_col = False)

# %%
#Importing products_consistency.csv dataframe
df_Prods = pd.read_csv(os.path.join(path, '02-Data', 'Prepared-Data', 'Products_data_Consistency.csv'), index_col = False)

# %%
df_ords
# Out:
#          Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                   1           1   2398795        1    prior             2
# 1                   2           2    473747        1    prior             3
# 2                   3           3   2254736        1    prior             4
# 3                   4           4    431534        1    prior             5
# 4                   5           5   3367565        1    prior             6
# ...               ...         ...       ...      ...      ...           ...
# 3214869       3421078     3421078   2266710   206209    prior            10
# 3214870       3421079     3421079   1854736   206209    prior            11
# 3214871       3421080     3421080    626363   206209    prior            12
# 3214872       3421081     3421081   2977660   206209    prior            13
# 3214873       3421082     3421082    272231   206209    train            14
#
# ...

# %%
df_ords_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3214874, 7)

# %%
df_ords = df_ords.drop('Unnamed: 0.1',axis=1)

# %%
df_ords
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                 1   2398795        1             2                   3
# 1                 2    473747        1             3                   3
# 2                 3   2254736        1             4                   4
# 3                 4    431534        1             5                   4
# 4                 5   3367565        1             6                   2
# ...             ...       ...      ...           ...                 ...
# 3214869     3421078   2266710   206209            10                   5
# 3214870     3421079   1854736   206209            11                   4
# 3214871     3421080    626363   206209            12                   1
# 3214872     3421081   2977660   206209            13                   1
# 3214873     3421082    272231   206209            14                   6
#
#          order_hour_of_day  days_since_prior_order
# ...

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id',how='outer', indicator = True)

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0         1.0   2398795      1.0           2.0                 3.0
# 1         1.0   2398795      1.0           2.0                 3.0
# 2         1.0   2398795      1.0           2.0                 3.0
# 3         1.0   2398795      1.0           2.0                 3.0
# 4         1.0   2398795      1.0           2.0                 3.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                7.0                    15.0       196.0                1.0
# 1                7.0                    15.0     10258.0                2.0
# 2                7.0                    15.0     12427.0                3.0
# 3                7.0                    15.0     13176.0                4.0
# 4                7.0                    15.0     26088.0                5.0
#
#    reordered _merge
# 0        1.0   both
# 1        0.0   both
# 2        1.0   both
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          30356421
# right_only     2078068
# left_only       206209
# Name: _merge, dtype: int64

# %%
df_merged_large.to_pickle(os.path.join(path, '02-Data','Prepared-Data', 'orders_products_combined.pkl'))

# %%
df_merged_large.to_csv(os.path.join(path, '02-Data','Prepared-Data', 'orders_products_combined.csv'))
