# %% [markdown]
# #importing libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # importing dataset order.csv

# %%
df = pd.read_csv(os.path.join(path,'02-Data','Original-Data','orders.csv'),index_col = False)

# %%
path = r'/Users/spathak/Instacart_Basket_Analysis'

# %%
path
# Out:
# '/Users/spathak/Instacart_Basket_Analysis'

# %% [markdown]
# # importing dataset prods.csv

# %%
df_Prods= pd.read_csv(os.path.join(path,'02-Data','Original-Data','products.csv'),index_col = False)

# %% [markdown]
# # Dropping Eval Set Coloum

# %%
#Dropping eval_Set column from orders.csv
df.drop(columns = ['eval_set'])
# Out:
#         order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0        2539329       1             1                   2                  8
# 1        2398795       1             2                   3                  7
# 2         473747       1             3                   3                 12
# 3        2254736       1             4                   4                  7
# 4         431534       1             5                   4                 15
# ...          ...     ...           ...                 ...                ...
# 3421078  2266710  206209            10                   5                 18
# 3421079  1854736  206209            11                   4                 10
# 3421080   626363  206209            12                   1                 12
# 3421081  2977660  206209            13                   1                 12
# 3421082   272231  206209            14                   6                 14
#
#          days_since_prior_order
# ...

# %%
# Value counts on days_since_prior_order column
df['days_since_prior_order'].value_counts(dropna = False)
# Out:
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: days_since_prior_order, dtype: int64

# %% [markdown]
# # Changing a variable data type,Question 1

# %%
# df_ords dataframe that doesn’t need to be included in analysis order_id,user_id
df.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
df['order_id'] = df['order_id'].astype('str')

# %%
df['order_id'].dtype
# Out:
# dtype('O')

# %%
df['user_id'] = df['user_id'].astype('str')

# %%
df['user_id'].dtype
# Out:
# dtype('O')

# %%
df.describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count  3.421083e+06        3.421083e+06       3.421083e+06
# mean   1.715486e+01        2.776219e+00       1.345202e+01
# std    1.773316e+01        2.046829e+00       4.226088e+00
# min    1.000000e+00        0.000000e+00       0.000000e+00
# 25%    5.000000e+00        1.000000e+00       1.000000e+01
# 50%    1.100000e+01        3.000000e+00       1.300000e+01
# 75%    2.300000e+01        5.000000e+00       1.600000e+01
# max    1.000000e+02        6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %% [markdown]
# # Question 4

# %%
#The busiest hour is 10.
df['order_hour_of_day'].value_counts()
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# # Question 3, Renaming coloum

# %%
# df_ords dataframe with an unintuitive name and change its name without overwriting the data frame.
df.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df.head()
# Out:
#   order_id user_id eval_set  order_number  orders_day_of_week  \
# 0  2539329       1    prior             1                   2
# 1  2398795       1    prior             2                   3
# 2   473747       1    prior             3                   3
# 3  2254736       1    prior             4                   4
# 4   431534       1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %% [markdown]
# # Importing Departments data

# %%
# # Assign path variable
path = r'/Users/spathak/Instacart_Basket_Analysis'

# %%
# Import  data set departments.csv
df_dep = pd.read_csv(os.path.join(path, '02-Data','Original-Data','departments.csv'), index_col = False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# Transposing df_dep
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Overwriting df_dep with transposed data
df_dep_t = df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# adding index to df_dep_t
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Take the first row of df_dep_t for the header
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# Create new dataframe that only copies over rows beyond the first row
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
# Set the header row as teh df header
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# # Creating Data Dictionaries,question 5

# %%
# Set df_dep_t_new dataframe to a dictionary
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_Prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#Find meaning of value 4 in the department_id column
print(data_dict.get('4'))
# Answer is Produce
# Out:
# {'department': 'produce'}

# %% [markdown]
# # Subsetting,QUESTION 6

# %%
# using loc to extract Breakfast subset
df_breakfast = df_Prods.loc[df_Prods['department_id']==14]

# %%
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# # Question 7

# %%
# using loc to extract alchol subset
df_alchol = df_Prods.loc[df_Prods['department_id']==5]

# %%
df_alchol.head()
# Out:
#      product_id                    product_name  aisle_id  department_id  \
# 51           52             Mirabelle Brut Rose       134              5
# 118         119          Chardonnay Paso Robles        62              5
# 149         150                       Brut Rosé       134              5
# 233         234               Tennessee Whiskey       124              5
# 248         249  Pinot Grigio, California, 2010        62              5
#
#      prices
# 51     14.4
# 118     5.5
# 149    12.9
# 233     3.1
# 248     2.7

# %%
# using loc to extract deli subset
df_deli = df_Prods.loc[df_Prods['department_id']==20]

# %%
df_deli.head()
# Out:
#      product_id                                   product_name  aisle_id  \
# 48           49  Vegetarian Grain Meat Sausages Italian - 4 CT        14
# 61           62        Premium Deli Oven Roasted Turkey Breast        96
# 73           74                Artisan Chick'n & Apple Sausage        14
# 84           85                           Soppressata Piccante        96
# 108         109                         Grape Leaf Hummus Wrap        13
#
#      department_id  prices
# 48              20    10.1
# 61              20    14.6
# 73              20     3.0
# 84              20     8.9
# 108             20     7.1

# %%
# using loc to extract beverages subset
df_beverages = df_Prods.loc[df_Prods['department_id']==7]

# %%
df_beverages.head()
# Out:
#     product_id                                    product_name  aisle_id  \
# 2            3            Robust Golden Unsweetened Oolong Tea        94
# 6            7                  Pure Coconut Water With Orange        98
# 9           10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                               Peach Mango Juice        31
# 19          20  Pomegranate Cranberry & Aloe Vera Enrich Drink        98
#
#     department_id  prices
# 2               7     4.5
# 6               7     4.4
# 9               7     8.4
# 10              7     2.8
# 19              7     6.0

# %%
# using loc to extract meat subset
df_meat= df_Prods.loc[df_Prods['department_id']==12]

# %%
df_meat.head()
# Out:
#     product_id                                       product_name  aisle_id  \
# 16          17                                  Rendered Duck Fat        35
# 22          23                             Organic Turkey Burgers        49
# 34          35     Italian Herb Porcini Mushrooms Chicken Sausage       106
# 39          40  Beef Hot Links Beef Smoked Sausage With Chile ...       106
# 83          84                                         Lamb Shank         7
#
#     department_id  prices
# 16             12    17.1
# 22             12     8.2
# 34             12    15.1
# 39             12    22.5
# 83             12    24.3

# %%
# using loc to extract seafood subset
df_seafood= df_Prods.loc[df_Prods['department_id']==12]

# %%
df_seafood.head()
# Out:
#     product_id                                       product_name  aisle_id  \
# 16          17                                  Rendered Duck Fat        35
# 22          23                             Organic Turkey Burgers        49
# 34          35     Italian Herb Porcini Mushrooms Chicken Sausage       106
# 39          40  Beef Hot Links Beef Smoked Sausage With Chile ...       106
# 83          84                                         Lamb Shank         7
#
#     department_id  prices
# 16             12    17.1
# 22             12     8.2
# 34             12    15.1
# 39             12    22.5
# 83             12    24.3

# %% [markdown]
# # Question 8

# %%
#Count of order data
df.shape
# Out:
# (3421083, 7)

# %%
#Count of Product data
df_Prods.shape
# Out:
# (49693, 5)

# %%
#Count of Department data
df_dep.shape
# Out:
# (1, 22)

# %%
# Create subset for user_id 1
df_userid_1 = df.loc[df['user_id']=='1']

# %%
df_userid_1
# Out:
#    order_id user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329       1    prior             1                   2
# 1   2398795       1    prior             2                   3
# 2    473747       1    prior             3                   3
# 3   2254736       1    prior             4                   4
# 4    431534       1    prior             5                   4
# 5   3367565       1    prior             6                   2
# 6    550135       1    prior             7                   1
# 7   3108588       1    prior             8                   1
# 8   2295261       1    prior             9                   1
# 9   2550362       1    prior            10                   4
# 10  1187899       1    train            11                   4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# 2                  12                    21.0
# ...

# %%
# summary statistics for user id 1
df_userid_1.describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count     11.000000           11.000000          11.000000
# mean       6.000000            2.636364          10.090909
# std        3.316625            1.286291           3.477198
# min        1.000000            1.000000           7.000000
# 25%        3.500000            1.500000           7.500000
# 50%        6.000000            3.000000           8.000000
# 75%        8.500000            4.000000          13.000000
# max       11.000000            4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
# Define Path
path = r'/Users/spathak/Instacart_Basket_Analysis'

# %% [markdown]
# # Question 12
#
# df.to_csv(os.path.join(path,'02-Data','Prepared Data','orders_wrangled.csv'))

# %% [markdown]
# # Question 13
# df_dep_t_new.to_csv(os.path.join(path, '02-Data','Prepared Data', 'departments_wrangled.csv'))

# %%
df.to_csv(os.path.join(path,'02-Data','Prepared Data','orders_wrangled.csv'))

# %%
df_dep_t_new.to_csv(os.path.join(path, '02-Data','Prepared Data', 'departments_wrangled.csv'))

# %%
path
# Out:
# '/Users/spathak/Instacart_Basket_Analysis'
