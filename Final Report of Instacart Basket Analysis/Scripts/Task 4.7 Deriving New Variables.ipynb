# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/spathak/Instacart_Basket_Analysis'

# %%
#Importing orders_products_merged.pkl dataframe

orders_products_merged = pd.read_pickle(os.path.join(path, '02-Data','Prepared-Data','orders_products_combined.pkl'))

# %% [markdown]
# # Question 1

# %%
df = orders_products_merged[:1000000]

# %%
orders_products_merged.head()
# Out:
#    Unnamed: 0_x   order_id  user_id  order_number  orders_day_of_week  \
# 0           1.0  2398795.0      1.0           2.0                 3.0
# 1           2.0   473747.0      1.0           3.0                 3.0
# 2           3.0  2254736.0      1.0           4.0                 4.0
# 3           4.0   431534.0      1.0           5.0                 4.0
# 4           5.0  3367565.0      1.0           6.0                 2.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                7.0                    15.0       196.0                1.0
# 1               12.0                    21.0       196.0                1.0
# 2                7.0                    29.0       196.0                1.0
# 3               15.0                    28.0       196.0                1.0
# 4                7.0                    19.0       196.0                1.0
#
#    reordered  Unnamed: 0_y product_name  aisle_id  department_id  prices  \
# ...

# %%
df.shape
# Out:
# (1000000, 16)

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/wh/wt_t75896090rmf4hk5j58j80000gq/T/ipykernel_22029/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# Mid-range product    462132
# Low-range product    331659
# Not enough data      206209
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.0

# %%
orders_products_merged ['orders_day_of_week'].value_counts(dropna=False)
# Out:
# 0.0    5827646
# 1.0    5340072
# 6.0    4224610
# 5.0    3983382
# 2.0    3976796
# 3.0    3628691
# 4.0    3583046
# NaN    2078218
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in orders_products_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
# ...

# %%
orders_products_merged ['busiest_day']=result

# %%
orders_products_merged ['busiest_day'].value_counts(dropna=False)
# Out:
# Regularly busy    23231769
# Busiest day        5827646
# Least busy         3583046
# Name: busiest_day, dtype: int64

# %% [markdown]
# # Question 2

# %%
# Frequency of orders of each day in a week
orders_products_merged ['orders_day_of_week'].value_counts(dropna=False)
# Out:
# 0.0    5827646
# 1.0    5340072
# 6.0    4224610
# 5.0    3983382
# 2.0    3976796
# 3.0    3628691
# 4.0    3583046
# NaN    2078218
# Name: orders_day_of_week, dtype: int64

# %%
# Creating array of busiest and slowest days values.
result = []

for value in orders_products_merged["orders_day_of_week"]:
    if value in (0,1):
        result.append("Busiest_days")
    elif value in (3,4):
        result.append("Slowest_days")
    else:
        result.append("Regular busy days")

# %%
result
# Out:
# ['Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Regular busy days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Slowest_days',
#  'Busiest_days',
#  'Regular busy days',
#  'Regular busy days',
#  'Busiest_days',
#  'Busiest_days',
#  'Regular busy days',
#  'Regular busy days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Regular busy days',
#  'Regular busy days',
#  'Busiest_days',
#  'Regular busy days',
#  'Regular busy days',
#  'Busiest_days',
#  'Regular busy days',
#  'Regular busy days',
#  'Regular busy days',
#  'Slowest_days',
#  'Regular busy days',
#  'Busiest_days',
#  'Busiest_days',
#  'Regular busy days',
#  'Slowest_days',
#  'Slowest_days',
#  'Regular busy days',
#  'Regular busy days',
#  'Busiest_days',
#  'Busiest_days',
#  'Regular busy days',
#  'Busiest_days',
#  'Busiest_days',
#  'Slowest_days',
# ...

# %%
# Merging results into the new coloum
orders_products_merged ['busiest_days']=result

# %%
# Frequency of busiest days values
orders_products_merged ['busiest_days'].value_counts(dropna=False)
# Out:
# Regular busy days    14263006
# Busiest_days         11167718
# Slowest_days          7211737
# Name: busiest_days, dtype: int64

# %% [markdown]
# # Another way of generating values using function

# %%
# Generating values by using function
def busiest_days(row):
    if row['orders_day_of_week'] in (0,1):
        return "Busiest days"
    elif row['orders_day_of_week'] in (3,4):
        return "Least Busiest days"
    else:
        return "Regular Busy day"

# %%
#  Merging results into the new coloum
orders_products_merged['busiest_days'] = orders_products_merged.apply(busiest_days, axis=1)

# %%
# Head of orders_products_merged dataframe
orders_products_merged.head
# Out:
# <bound method NDFrame.head of           Unnamed: 0_x   order_id  user_id  order_number  orders_day_of_week  \
# 0                  1.0  2398795.0      1.0           2.0                 3.0
# 1                  2.0   473747.0      1.0           3.0                 3.0
# 2                  3.0  2254736.0      1.0           4.0                 4.0
# 3                  4.0   431534.0      1.0           5.0                 4.0
# 4                  5.0  3367565.0      1.0           6.0                 2.0
# ...                ...        ...      ...           ...                 ...
# 32642456           NaN        NaN      NaN           NaN                 NaN
# 32642457           NaN        NaN      NaN           NaN                 NaN
# 32642458           NaN        NaN      NaN           NaN                 NaN
# 32642459           NaN        NaN      NaN           NaN                 NaN
# 32642460           NaN        NaN      NaN           NaN                 NaN
#
# ...

# %% [markdown]
# # Question 3

# %%
# Frequency of order_hour_of_day values
orders_products_merged ['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 10.0    2612897
# 11.0    2583755
# 14.0    2537123
# 15.0    2507436
# 13.0    2506651
# 12.0    2464761
# 16.0    2383828
# 9.0     2328117
# NaN     2078218
# 17.0    1960365
# 8.0     1634105
# 18.0    1534275
# 19.0    1179207
# 20.0     917052
# 7.0      850740
# 21.0     751646
# 22.0     596866
# 23.0     378622
# 6.0      276831
# 0.0      205028
# 1.0      109000
# 5.0       83405
# 2.0       64488
# 4.0       49797
# 3.0       48248
# Name: order_hour_of_day, dtype: int64

# %%
 #  Creating array of most orders,fewest orders and average orders values
result = []

for value in orders_products_merged["order_hour_of_day"]:
  if value in (9,10,11,12,13,14,15,16):
    result.append("Most orders")
  elif value in (0,1,2,3,4,5,6,23):
    result.append("Fewest orders")
  else:
    result.append("Aaverage orders")

# %%
result
# Out:
# ['Aaverage orders',
#  'Most orders',
#  'Aaverage orders',
#  'Most orders',
#  'Aaverage orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Aaverage orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Aaverage orders',
#  'Most orders',
#  'Aaverage orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Aaverage orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Aaverage orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
# merging results into the new coloum
orders_products_merged ['busiest_period_of_day']=result

# %%
# head of orders_products_merged
orders_products_merged.head()
# Out:
#    Unnamed: 0_x   order_id  user_id  order_number  orders_day_of_week  \
# 0           1.0  2398795.0      1.0           2.0                 3.0
# 1           2.0   473747.0      1.0           3.0                 3.0
# 2           3.0  2254736.0      1.0           4.0                 4.0
# 3           4.0   431534.0      1.0           5.0                 4.0
# 4           5.0  3367565.0      1.0           6.0                 2.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                7.0                    15.0       196.0                1.0
# 1               12.0                    21.0       196.0                1.0
# 2                7.0                    29.0       196.0                1.0
# 3               15.0                    28.0       196.0                1.0
# 4                7.0                    19.0       196.0                1.0
#
#    reordered  Unnamed: 0_y product_name  aisle_id  department_id  prices  \
# ...

# %%
# frequency of busiest_period_of_day values
orders_products_merged ['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# Most orders        19924568
# Aaverage orders    11502474
# Fewest orders       1215419
# Name: busiest_period_of_day, dtype: int64

# %%
# Export data to pkl

orders_products_merged.to_pickle(os.path.join(path, '02-Data','Prepared-Data', 'orders_products_merged_busiest.pkl'))
